# %% [markdown]
# # 02 - Preprocessing and Feature Engineering
#
# Inspect engineered features and the fitted preprocessing design.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.config import TARGET_COLUMN
from src.data import load_raw_data, split_features_target
from src.features import add_features, infer_feature_columns, make_preprocessor

train, test, _ = load_raw_data()
X, y = split_features_target(train)
X_features = add_features(X)
X_features.head()
# Out:
#    id  yas cinsiyet            meslek  vucut_kitle_indeksi          ulke  \
# 0   1   34    Erkek  Saglik Personeli            31.470103           Cin
# 1   2   32    Kadin          Muhendis            30.981394       Amerika
# 2   3   39    Erkek         Ev Hanimi            21.533898         Spain
# 3   4   40    Kadin          Egitimci            23.310749  Yeni Zelanda
# 4   5   36    Kadin               NaN                  NaN      Portekiz
#
#    rem_yuzdesi  derin_uyku_yuzdesi  uykuya_dalma_suresi_dk  \
# 0    14.431210           14.645436                      27
# 1    21.771870           27.220360                      20
# 2    18.178857           25.530104                      33
# 3    21.438151           15.891188                      21
# 4    25.468018           16.356738                      21
#
#    gecelik_uyanma_sayisi  ...  hafta_sonu_mu  saglikli_mi  gece_insani_mi  \
# 0                      7  ...            0.0          0.0             0.0
# 1                      4  ...            0.0          1.0             1.0
# 2                      7  ...            1.0          0.0             0.0
# 3                      2  ...            1.0          1.0             1.0
# 4                      8  ...            0.0          0.0             0.0
#
#        hafta_sonu_kronotip           mevsim_gun_tipi  \
# 0  Hafta ici__Sabah insani   Sonbahar-Kis__Hafta ici
# 1   Hafta ici__Gece insani   Sonbahar-Kis__Hafta ici
# 2         Hafta sonu__Notr  Ilkbahar-Yaz__Hafta sonu
# 3  Hafta sonu__Gece insani  Sonbahar-Kis__Hafta sonu
# 4          Hafta ici__Notr   Sonbahar-Kis__Hafta ici
#
#                            ruh_kronotip              meslek_gun_tipi  \
# 0  Anksiyete ve depresyon__Sabah insani  Saglik Personeli__Hafta ici
# 1                 Saglikli__Gece insani          Muhendis__Hafta ici
# 2                       Depresyon__Notr        Ev Hanimi__Hafta sonu
# 3                 Saglikli__Gece insani         Egitimci__Hafta sonu
# 4          Anksiyete ve depresyon__Notr           Missing__Hafta ici
#
#   yas_grubu  bmi_sinifi  stres_grubu
# 0     25-34      obez_1   cok_yuksek
# 1     25-34      obez_1       yuksek
# 2     35-44      normal       yuksek
# 3     35-44      normal         orta
# 4     35-44         NaN       yuksek
#
# [5 rows x 57 columns]

# %%
numeric_columns, categorical_columns = infer_feature_columns(X)
print(f'Numeric features: {len(numeric_columns)}')
print(f'Categorical features: {len(categorical_columns)}')
display(numeric_columns)
display(categorical_columns)
# Out:
# Numeric features: 41
# Categorical features: 15
# ['yas',
#  'vucut_kitle_indeksi',
#  'rem_yuzdesi',
#  'derin_uyku_yuzdesi',
#  'uykuya_dalma_suresi_dk',
#  'gecelik_uyanma_sayisi',
#  'uyku_oncesi_kafein_mg',
#  'uyku_oncesi_ekran_suresi_dk',
#  'gunluk_adim_sayisi',
#  'sekerleme_suresi_dk',
#  'stres_skoru',
#  'gunluk_calisma_saati',
#  'dinlenik_nabiz_bpm',
#  'oda_sicakligi_celsius',
#  'hafta_sonu_uyku_farki_saat',
#  'toplam_rem_derin_uyku_yuzdesi',
#  'rem_derin_orani',
#  'derin_rem_orani',
#  'uyku_kalitesi_proxy',
#  'uyku_bolunme_yuku',
#  'uyku_bolunme_skoru',
#  'uyku_oncesi_uyarici_yuk',
#  'kafein_ekran_carpim',
#  'adim_bin',
#  'aktivite_calisma_orani',
#  'adim_bin_per_saat',
#  'stres_calisma_carpim',
#  'stres_uyku_bolunme_carpim',
#  'stres_kalitesi_orani',
#  'dinlenme_yuku',
#  'kardiyo_yuk',
#  'ideal_sicaklik_farki',
#  'hafta_sonu_fark_abs',
#  'hafta_sonu_fark_pozitif',
#  'yas_kare',
#  'bmi_kare',
#  'sekerleme_saat',
#  'sekerleme_uzun_mu',
#  'hafta_sonu_mu',
#  'saglikli_mi',
#  'gece_insani_mi']
# ['cinsiyet',
#  'meslek',
#  'ulke',
#  'kronotip',
#  'ruh_sagligi_durumu',
#  'mevsim',
#  'gun_tipi',
#  'ulke_norm',
#  'hafta_sonu_kronotip',
#  'mevsim_gun_tipi',
#  'ruh_kronotip',
#  'meslek_gun_tipi',
#  'yas_grubu',
#  'bmi_sinifi',
#  'stres_grubu']

# %%
preprocessor = make_preprocessor(X)
Xt = preprocessor.fit_transform(add_features(X), y)
Xt.shape
# Out:
# (56000, 178)

# %%
feature_names = preprocessor.get_feature_names_out()
feature_names[:30], len(feature_names)
# Out:
# (array(['yas', 'vucut_kitle_indeksi', 'rem_yuzdesi', 'derin_uyku_yuzdesi',
#         'uykuya_dalma_suresi_dk', 'gecelik_uyanma_sayisi',
#         'uyku_oncesi_kafein_mg', 'uyku_oncesi_ekran_suresi_dk',
#         'gunluk_adim_sayisi', 'sekerleme_suresi_dk', 'stres_skoru',
#         'gunluk_calisma_saati', 'dinlenik_nabiz_bpm',
#         'oda_sicakligi_celsius', 'hafta_sonu_uyku_farki_saat',
#         'toplam_rem_derin_uyku_yuzdesi', 'rem_derin_orani',
#         'derin_rem_orani', 'uyku_kalitesi_proxy', 'uyku_bolunme_yuku',
#         'uyku_bolunme_skoru', 'uyku_oncesi_uyarici_yuk',
#         'kafein_ekran_carpim', 'adim_bin', 'aktivite_calisma_orani',
#         'adim_bin_per_saat', 'stres_calisma_carpim',
#         'stres_uyku_bolunme_carpim', 'stres_kalitesi_orani',
#         'dinlenme_yuku'], dtype=object),
#  178)
