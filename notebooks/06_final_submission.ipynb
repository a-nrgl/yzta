# %% [markdown]
# # 06 - Final Submission
#
# Generate and validate the final submission file from the saved model.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

# %cd {PROJECT_ROOT}
# !python -m src.predict --model-path models/final_model.joblib --output-path data/submissions/submission_latest.csv

# %%
import pandas as pd

submission = pd.read_csv('data/submissions/submission_latest.csv')
test = pd.read_csv('data/raw/test_x.csv')

assert list(submission.columns) == ['id', 'bilissel_performans_skoru']
assert len(submission) == len(test)
assert submission['id'].equals(test['id'])
assert submission['bilissel_performans_skoru'].between(0, 10).all()
submission.head()
